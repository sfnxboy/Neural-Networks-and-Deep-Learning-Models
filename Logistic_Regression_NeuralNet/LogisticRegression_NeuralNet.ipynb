# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# For our purposes, we'll use our basic logistic regression parameters, which include:
#
# - The solver parameter is set to 'lbfgs', which is an algorithm for learning and optimization. The particular solver isn't very important in this example, but note that a number of optimizers exist.
# - The max_iter parameter will be set to 200 iterations, which will give the model sufficient opportunity to converge on effective weights
#
# Putting all of our arguments together, we'll add and run the following code in the notebook:

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %% [markdown]
# Next, we need to build, compile, and evaluate our basic neural network model. Again, we'll use our typical binary classifier parameters:
#
# - Our single hidden layer will have an input_dim equal to 8, 16 neuron units, and will use the relu activation function.
# - The loss function should be binary_crossentropy, using the adam optimizer.
# - Our model should provide the additional accuracy scoring metric and train over a maximum of 50 epochs.
#
# Training the neural network model through 50 epochs will limit the risk of over fitting the model.

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 443us/step - loss: 0.8194 - accuracy: 0.3854
# Epoch 2/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.7639 - accuracy: 0.4392
# Epoch 3/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.7174 - accuracy: 0.5156
# Epoch 4/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.6826 - accuracy: 0.5990
# Epoch 5/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.6550 - accuracy: 0.6319
# Epoch 6/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.6302 - accuracy: 0.6562
# Epoch 7/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.6120 - accuracy: 0.6788
# Epoch 8/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.5952 - accuracy: 0.6944
# Epoch 9/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.5809 - accuracy: 0.6979
# Epoch 10/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.5685 - accuracy: 0.7118
# Epoch 11/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.5571 - accuracy: 0.7240
# Epoch 12/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.5469 - accuracy: 0.7309
# Epoch 13/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.5374 - accuracy: 0.7413
# Epoch 14/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.5288 - accuracy: 0.7500
# Epoch 15/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.5212 - accuracy: 0.7639
# Epoch 16/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.5136 - accuracy: 0.7778
# Epoch 17/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.5070 - accuracy: 0.7830
# Epoch 18/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.5006 - accuracy: 0.7847
# Epoch 19/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.4951 - accuracy: 0.7899
# Epoch 20/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4893 - accuracy: 0.7899
# Epoch 21/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4846 - accuracy: 0.7899
# Epoch 22/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4802 - accuracy: 0.7899
# Epoch 23/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4760 - accuracy: 0.7951
# Epoch 24/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4722 - accuracy: 0.7969
# Epoch 25/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4694 - accuracy: 0.7969
# Epoch 26/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4662 - accuracy: 0.7899
# Epoch 27/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4635 - accuracy: 0.7934
# Epoch 28/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4617 - accuracy: 0.7882
# Epoch 29/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4592 - accuracy: 0.7882
# Epoch 30/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4575 - accuracy: 0.7917
# Epoch 31/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4558 - accuracy: 0.7917
# Epoch 32/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4542 - accuracy: 0.7899
# Epoch 33/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.4529 - accuracy: 0.7899
# Epoch 34/50
# 18/18 [==============================] - 0s 334us/step - loss: 0.4517 - accuracy: 0.7899
# Epoch 35/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4505 - accuracy: 0.7934
# Epoch 36/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4496 - accuracy: 0.7917
# Epoch 37/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4485 - accuracy: 0.7917
# Epoch 38/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4478 - accuracy: 0.7934
# Epoch 39/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.4466 - accuracy: 0.7969
# Epoch 40/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4461 - accuracy: 0.7934
# Epoch 41/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.4452 - accuracy: 0.7934
# Epoch 42/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.4443 - accuracy: 0.7951
# Epoch 43/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4437 - accuracy: 0.7934
# Epoch 44/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4431 - accuracy: 0.7917
# Epoch 45/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4427 - accuracy: 0.7934
# Epoch 46/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4415 - accuracy: 0.7934
# Epoch 47/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.4413 - accuracy: 0.7934
# Epoch 48/50
# 18/18 [==============================] - 0s 334us/step - loss: 0.4408 - accuracy: 0.7899
# Epoch 49/50
# 18/18 [==============================] - 0s 389us/step - loss: 0.4401 - accuracy: 0.7899
# Epoch 50/50
# 18/18 [==============================] - 0s 445us/step - loss: 0.4394 - accuracy: 0.7899
# 6/6 - 0s - loss: 0.4695 - accuracy: 0.7500
# Loss: 0.4695397615432739, Accuracy: 0.75
